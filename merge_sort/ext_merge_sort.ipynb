# %%
import random

def generate_dummy_dataset(filename, num_elements):
    with open(filename, 'w') as file:
        for _ in range(num_elements):
            file.write(str(random.randint(1, 1000)) + '\n')

# Generate a file 'dummy_dataset.txt' with 1000 random integers
generate_dummy_dataset('dummy_dataset.txt', 1000)

# %%
import heapq
import sys
import os

def read_chunk(file, chunk_size):
    chunk = []
    for _ in range(chunk_size):
        line = file.readline()
        if not line:
            break
        chunk.append(int(line.strip()))
    # print(f"{chunk = }")
    return chunk

# %%
def external_merge_sort(input_file, output_file, chunk_size):
    # Phase 1: Sort individual chunks internally
    with open(input_file, 'r') as infile:
        chunk_count = 0
        while True:
            chunk = read_chunk(infile, chunk_size)
            if not chunk:
                break
            chunk.sort()
            chunk_count += 1
            with open(f'chunk_{chunk_count}.txt', 'w') as chunk_file:
                for item in chunk:
                    # print(f"{item =}")
                    chunk_file.write(str(item) + '\n')
                    
    chunks = []
    # Phase 2: Merge sorted chunks
    for i in range(1, chunk_count+1):
        chunks.append(open(f'chunk_{i}.txt'))
        
    heap = []    
    with open(output_file, 'w') as outfile:
        for i, chunk in enumerate(chunks):
            heap.append((int(chunk.readline().strip()), i))
            heapq.heapify(heap)
        print(f"min-heap: {heap}")
        print(".......................................................")
        while heap:
            print("########################################################")
            smallest, chunk_idx = heapq.heappop(heap)
            print(f"{smallest = }, {chunk_idx =}")
            print(f"heappop: {heap}")
            
            outfile.write(f'{smallest}\n')
            next_item = chunks[chunk_idx].readline().strip()
            if next_item:
                heapq.heappush(heap, (int(next_item), chunk_idx))
                print(f"heappush: {heap}")

    # Clean up temporary chunk files
    for i in range(1, chunk_count+1):
        filename = f'chunk_{i}.txt'
        os.remove(filename)

# Perform external merge sort on 'dummy_dataset.txt'
external_merge_sort('dummy_dataset.txt', 'sorted_dataset.txt', chunk_size=100)
# Out:
# min-heap: [(2, 3), (3, 4), (6, 2), (8, 0), (5, 1), (28, 5), (11, 6), (22, 7), (24, 8), (5, 9)]
# .......................................................
# ########################################################
# smallest = 2, chunk_idx =3
# heappop: [(3, 4), (5, 1), (6, 2), (8, 0), (5, 9), (28, 5), (11, 6), (22, 7), (24, 8)]
# heappush: [(3, 4), (5, 1), (6, 2), (8, 0), (5, 9), (28, 5), (11, 6), (22, 7), (24, 8), (7, 3)]
# ########################################################
# smallest = 3, chunk_idx =4
# heappop: [(5, 1), (5, 9), (6, 2), (8, 0), (7, 3), (28, 5), (11, 6), (22, 7), (24, 8)]
# heappush: [(5, 1), (5, 9), (6, 2), (8, 0), (7, 3), (28, 5), (11, 6), (22, 7), (24, 8), (8, 4)]
# ########################################################
# smallest = 5, chunk_idx =1
# heappop: [(5, 9), (7, 3), (6, 2), (8, 0), (8, 4), (28, 5), (11, 6), (22, 7), (24, 8)]
# heappush: [(5, 9), (7, 3), (6, 2), (8, 0), (8, 4), (28, 5), (11, 6), (22, 7), (24, 8), (31, 1)]
# ########################################################
# smallest = 5, chunk_idx =9
# heappop: [(6, 2), (7, 3), (11, 6), (8, 0), (8, 4), (28, 5), (31, 1), (22, 7), (24, 8)]
# heappop: [(16, 6), (22, 7), (28, 5), (24, 8), (23, 9), (30, 2), (31, 1), (33, 3), (40, 4)]
# heappush: [(14, 0), (16, 6), (28, 5), (24, 8), (22, 7), (30, 2), (31, 1), (33, 3), (40, 4), (23, 9)]
# ########################################################
# smallest = 14, chunk_idx =0
# heappop: [(16, 6), (22, 7), (28, 5), (24, 8), (23, 9), (30, 2), (31, 1), (33, 3), (40, 4)]
# heappush: [(16, 0), (16, 6), (28, 5), (24, 8), (22, 7), (30, 2), (31, 1), (33, 3), (40, 4), (23, 9)]
# ########################################################
# smallest = 16, chunk_idx =0
# heappop: [(16, 6), (22, 7), (28, 5), (24, 8), (23, 9), (30, 2), (31, 1), (33, 3), (40, 4)]
# heappush: [(16, 6), (21, 0), (28, 5), (24, 8), (22, 7), (30, 2), (31, 1), (33, 3), (40, 4), (23, 9)]
# ########################################################
# smallest = 16, chunk_idx =6
# heappop: [(21, 0), (22, 7), (28, 5), (24, 8), (23, 9), (30, 2), (31, 1), (33, 3), (40, 4)]
# heappush: [(21, 0), (22, 7), (28, 5), (24, 8), (23, 9), (30, 2), (31, 1), (33, 3), (40, 4), (42, 6)]
# ########################################################
# smallest = 21, chunk_idx =0
# heappop: [(22, 7), (23, 9), (28, 5), (24, 8), (42, 6), (30, 2), (31, 1), (33, 3), (40, 4)]
# heappush: [(22, 7), (23, 9), (28, 5), (24, 8), (24, 0), (30, 2), (31, 1), (33, 3), (40, 4), (42, 6)]
# ########################################################
# smallest = 22, chunk_idx =7
# heappop: [(23, 9), (24, 0), (28, 5), (24, 8), (42, 6), (30, 2), (31, 1), (33, 3), (40, 4)]
# heappush: [(23, 9), (24, 0), (28, 5), (24, 8), (25, 7), (30, 2), (31, 1), (33, 3), (40, 4), (42, 6)]
# ########################################################
# smallest = 23, chunk_idx =9
# heappop: [(24, 0), (24, 8), (28, 5), (33, 3), (25, 7), (30, 2), (31, 1), (42, 6), (40, 4)]
# heappush: [(24, 0), (24, 8), (28, 5), (33, 3), (25, 7), (30, 2), (31, 1), (42, 6), (40, 4), (27, 9)]
# ########################################################
# smallest = 24, chunk_idx =0
# heappop: [(24, 8), (25, 7), (28, 5), (33, 3), (27, 9), (30, 2), (31, 1), (42, 6), (40, 4)]
# heappush: [(24, 8), (25, 7), (28, 5), (33, 3), (27, 0), (30, 2), (31, 1), (42, 6), (40, 4), (27, 9)]
# ########################################################
# smallest = 24, chunk_idx =8
# heappop: [(25, 7), (27, 0), (28, 5), (33, 3), (27, 9), (30, 2), (31, 1), (42, 6), (40, 4)]
# heappush: [(25, 7), (27, 0), (28, 5), (33, 3), (27, 9), (30, 2), (31, 1), (42, 6), (40, 4), (28, 8)]
# ########################################################
# smallest = 25, chunk_idx =7
# heappop: [(27, 0), (27, 9), (28, 5), (33, 3), (28, 8), (30, 2), (31, 1), (42, 6), (40, 4)]
# heappush: [(27, 0), (27, 7), (28, 5), (33, 3), (27, 9), (30, 2), (31, 1), (42, 6), (40, 4), (28, 8)]
# ########################################################
# smallest = 27, chunk_idx =0
# heappop: [(27, 7), (27, 9), (28, 5), (33, 3), (28, 8), (30, 2), (31, 1), (42, 6), (40, 4)]
# heappush: [(27, 7), (27, 9), (28, 5), (33, 3), (28, 8), (30, 2), (31, 1), (42, 6), (40, 4), (37, 0)]
# ########################################################
# smallest = 27, chunk_idx =7
# heappop: [(27, 9), (28, 8), (28, 5), (33, 3), (37, 0), (30, 2), (31, 1), (42, 6), (40, 4)]
# heappush: [(27, 9), (28, 8), (28, 5), (33, 3), (37, 0), (30, 2), (31, 1), (42, 6), (40, 4), (37, 7)]
# ########################################################
# smallest = 27, chunk_idx =9
# heappop: [(28, 5), (28, 8), (30, 2), (33, 3), (37, 0), (37, 7), (31, 1), (42, 6), (40, 4)]
# heappush: [(28, 5), (28, 8), (30, 2), (33, 3), (37, 0), (37, 7), (31, 1), (42, 6), (40, 4), (56, 9)]
# ########################################################
# smallest = 28, chunk_idx =5
# heappop: [(28, 8), (33, 3), (30, 2), (40, 4), (37, 0), (37, 7), (31, 1), (42, 6), (56, 9)]
# heappush: [(28, 8), (29, 5), (30, 2), (40, 4), (33, 3), (37, 7), (31, 1), (42, 6), (56, 9), (37, 0)]
# ########################################################
# smallest = 28, chunk_idx =8
# heappop: [(29, 5), (33, 3), (30, 2), (40, 4), (37, 0), (37, 7), (31, 1), (42, 6), (56, 9)]
# heappush: [(29, 5), (32, 8), (30, 2), (40, 4), (33, 3), (37, 7), (31, 1), (42, 6), (56, 9), (37, 0)]
# ########################################################
# smallest = 29, chunk_idx =5
# heappop: [(30, 2), (32, 8), (31, 1), (40, 4), (33, 3), (37, 7), (37, 0), (42, 6), (56, 9)]
# heappush: [(30, 2), (32, 8), (31, 1), (40, 4), (33, 3), (37, 7), (37, 0), (42, 6), (56, 9), (38, 5)]
# ########################################################
# smallest = 30, chunk_idx =2
# heappop: [(31, 1), (32, 8), (37, 0), (40, 4), (33, 3), (37, 7), (38, 5), (42, 6), (56, 9)]
# heappush: [(31, 1), (32, 8), (37, 0), (40, 4), (33, 3), (37, 7), (38, 5), (42, 6), (56, 9), (51, 2)]
# ########################################################
# smallest = 31, chunk_idx =1
# heappop: [(32, 8), (33, 3), (37, 0), (40, 4), (51, 2), (37, 7), (38, 5), (42, 6), (56, 9)]
# heappush: [(32, 8), (33, 3), (37, 0), (40, 4), (36, 1), (37, 7), (38, 5), (42, 6), (56, 9), (51, 2)]
# ########################################################
# smallest = 32, chunk_idx =8
# heappop: [(33, 3), (36, 1), (37, 0), (40, 4), (51, 2), (37, 7), (38, 5), (42, 6), (56, 9)]
# heappush: [(33, 3), (36, 1), (37, 0), (40, 4), (50, 8), (37, 7), (38, 5), (42, 6), (56, 9), (51, 2)]
# ########################################################
# smallest = 33, chunk_idx =3
# heappop: [(36, 1), (40, 4), (37, 0), (42, 6), (50, 8), (37, 7), (38, 5), (51, 2), (56, 9)]
# heappush: [(35, 3), (36, 1), (37, 0), (42, 6), (40, 4), (37, 7), (38, 5), (51, 2), (56, 9), (50, 8)]
# ########################################################
# heappop: [(93, 2), (94, 9), (94, 5), (102, 7), (98, 6), (101, 8), (96, 4), (131, 1), (106, 3)]
# heappush: [(93, 2), (94, 9), (94, 5), (102, 7), (98, 6), (101, 8), (96, 4), (131, 1), (106, 3), (106, 0)]
# ########################################################
# smallest = 93, chunk_idx =2
# heappop: [(94, 5), (94, 9), (96, 4), (102, 7), (98, 6), (101, 8), (106, 0), (131, 1), (106, 3)]
# heappush: [(94, 5), (94, 9), (96, 4), (102, 7), (98, 6), (101, 8), (106, 0), (131, 1), (106, 3), (101, 2)]
# ########################################################
# smallest = 94, chunk_idx =5
# heappop: [(94, 9), (98, 6), (96, 4), (102, 7), (101, 2), (101, 8), (106, 0), (131, 1), (106, 3)]
# heappush: [(94, 9), (98, 6), (96, 4), (102, 7), (101, 2), (101, 8), (106, 0), (131, 1), (106, 3), (101, 5)]
# ########################################################
# smallest = 94, chunk_idx =9
# heappop: [(96, 4), (98, 6), (101, 5), (102, 7), (101, 2), (101, 8), (106, 0), (131, 1), (106, 3)]
# heappush: [(96, 4), (98, 6), (101, 5), (102, 7), (101, 2), (101, 8), (106, 0), (131, 1), (106, 3), (127, 9)]
# ########################################################
# smallest = 96, chunk_idx =4
# heappop: [(98, 6), (101, 2), (101, 5), (102, 7), (127, 9), (101, 8), (106, 0), (131, 1), (106, 3)]
# heappush: [(97, 4), (98, 6), (101, 5), (102, 7), (101, 2), (101, 8), (106, 0), (131, 1), (106, 3), (127, 9)]
# ########################################################
# smallest = 97, chunk_idx =4
# heappop: [(98, 6), (101, 2), (101, 5), (102, 7), (127, 9), (101, 8), (106, 0), (131, 1), (106, 3)]
# heappush: [(97, 4), (98, 6), (101, 5), (102, 7), (101, 2), (101, 8), (106, 0), (131, 1), (106, 3), (127, 9)]
# ########################################################
# smallest = 97, chunk_idx =4
# heappop: [(98, 6), (101, 2), (101, 5), (102, 7), (127, 9), (101, 8), (106, 0), (131, 1), (106, 3)]
# heappush: [(98, 6), (100, 4), (101, 5), (102, 7), (101, 2), (101, 8), (106, 0), (131, 1), (106, 3), (127, 9)]
# ########################################################
# smallest = 98, chunk_idx =6
# heappop: [(100, 4), (101, 2), (101, 5), (102, 7), (127, 9), (101, 8), (106, 0), (131, 1), (106, 3)]
# heappush: [(100, 4), (101, 2), (101, 5), (102, 7), (102, 6), (101, 8), (106, 0), (131, 1), (106, 3), (127, 9)]
# ########################################################
# smallest = 100, chunk_idx =4
# heappop: [(101, 2), (102, 6), (101, 5), (102, 7), (127, 9), (101, 8), (106, 0), (131, 1), (106, 3)]
# heappush: [(101, 2), (102, 6), (101, 5), (102, 7), (105, 4), (101, 8), (106, 0), (131, 1), (106, 3), (127, 9)]
# ########################################################
# smallest = 101, chunk_idx =2
# heappop: [(101, 5), (102, 6), (101, 8), (102, 7), (105, 4), (127, 9), (106, 0), (131, 1), (106, 3)]
# heappush: [(101, 5), (102, 6), (101, 8), (102, 7), (105, 4), (127, 9), (106, 0), (131, 1), (106, 3), (116, 2)]
# ########################################################
# smallest = 101, chunk_idx =5
# ########################################################
# smallest = 121, chunk_idx =5
# heappop: [(121, 6), (121, 8), (122, 3), (125, 7), (123, 0), (127, 9), (126, 2), (131, 1), (135, 4)]
# heappush: [(121, 6), (121, 8), (122, 3), (125, 7), (123, 0), (127, 9), (126, 2), (131, 1), (135, 4), (130, 5)]
# ########################################################
# smallest = 121, chunk_idx =6
# heappop: [(121, 8), (123, 0), (122, 3), (125, 7), (130, 5), (127, 9), (126, 2), (131, 1), (135, 4)]
# heappush: [(121, 8), (123, 0), (122, 3), (125, 7), (127, 6), (127, 9), (126, 2), (131, 1), (135, 4), (130, 5)]
# ########################################################
# smallest = 121, chunk_idx =8
# heappop: [(122, 3), (123, 0), (126, 2), (125, 7), (127, 6), (127, 9), (130, 5), (131, 1), (135, 4)]
# heappush: [(122, 3), (123, 0), (126, 2), (125, 7), (127, 6), (127, 9), (130, 5), (131, 1), (135, 4), (152, 8)]
# ########################################################
# smallest = 122, chunk_idx =3
# heappop: [(123, 0), (125, 7), (126, 2), (131, 1), (127, 6), (127, 9), (130, 5), (152, 8), (135, 4)]
# heappush: [(123, 0), (125, 7), (126, 2), (131, 1), (127, 6), (127, 9), (130, 5), (152, 8), (135, 4), (144, 3)]
# ########################################################
# smallest = 123, chunk_idx =0
# heappop: [(125, 7), (127, 6), (126, 2), (131, 1), (144, 3), (127, 9), (130, 5), (152, 8), (135, 4)]
# heappush: [(125, 7), (127, 6), (126, 2), (131, 1), (132, 0), (127, 9), (130, 5), (152, 8), (135, 4), (144, 3)]
# ########################################################
# smallest = 125, chunk_idx =7
# heappop: [(126, 2), (127, 6), (127, 9), (131, 1), (132, 0), (144, 3), (130, 5), (152, 8), (135, 4)]
# heappush: [(126, 2), (127, 6), (127, 9), (131, 1), (132, 0), (144, 3), (130, 5), (152, 8), (135, 4), (141, 7)]
# ########################################################
# smallest = 126, chunk_idx =2
# heappop: [(127, 6), (131, 1), (127, 9), (135, 4), (132, 0), (144, 3), (130, 5), (152, 8), (141, 7)]
# heappush: [(127, 6), (131, 1), (127, 9), (135, 4), (132, 0), (144, 3), (130, 5), (152, 8), (141, 7), (139, 2)]
# ########################################################
# smallest = 127, chunk_idx =6
# heappop: [(127, 9), (131, 1), (130, 5), (135, 4), (132, 0), (144, 3), (139, 2), (152, 8), (141, 7)]
# heappush: [(127, 9), (131, 1), (130, 5), (135, 4), (132, 0), (144, 3), (139, 2), (152, 8), (141, 7), (148, 6)]
# ########################################################
# smallest = 127, chunk_idx =9
# heappop: [(130, 5), (131, 1), (139, 2), (135, 4), (132, 0), (144, 3), (148, 6), (152, 8), (141, 7)]
# heappush: [(130, 5), (131, 1), (139, 2), (135, 4), (132, 0), (144, 3), (148, 6), (152, 8), (141, 7), (140, 9)]
# ########################################################
# smallest = 130, chunk_idx =5
# heappop: [(131, 1), (132, 0), (139, 2), (135, 4), (140, 9), (144, 3), (148, 6), (152, 8), (141, 7)]
# heappush: [(131, 1), (132, 0), (139, 2), (135, 4), (133, 5), (144, 3), (148, 6), (152, 8), (141, 7), (140, 9)]
# ########################################################
# smallest = 946, chunk_idx =7
# heappop: [(947, 5), (954, 0), (948, 8), (971, 3), (959, 9), (953, 2), (958, 1), (975, 6), (971, 4)]
# heappush: [(947, 5), (954, 0), (948, 8), (971, 3), (959, 9), (953, 2), (958, 1), (975, 6), (971, 4), (967, 7)]
# ########################################################
# smallest = 947, chunk_idx =5
# heappop: [(948, 8), (954, 0), (953, 2), (971, 3), (959, 9), (967, 7), (958, 1), (975, 6), (971, 4)]
# heappush: [(948, 8), (950, 5), (953, 2), (971, 3), (954, 0), (967, 7), (958, 1), (975, 6), (971, 4), (959, 9)]
# ########################################################
# smallest = 948, chunk_idx =8
# heappop: [(950, 5), (954, 0), (953, 2), (971, 3), (959, 9), (967, 7), (958, 1), (975, 6), (971, 4)]
# heappush: [(950, 5), (954, 0), (953, 2), (971, 3), (959, 9), (967, 7), (958, 1), (975, 6), (971, 4), (969, 8)]
# ########################################################
# smallest = 950, chunk_idx =5
# heappop: [(953, 2), (954, 0), (958, 1), (971, 3), (959, 9), (967, 7), (969, 8), (975, 6), (971, 4)]
# heappush: [(950, 5), (953, 2), (958, 1), (971, 3), (954, 0), (967, 7), (969, 8), (975, 6), (971, 4), (959, 9)]
# ########################################################
# smallest = 950, chunk_idx =5
# heappop: [(953, 2), (954, 0), (958, 1), (971, 3), (959, 9), (967, 7), (969, 8), (975, 6), (971, 4)]
# heappush: [(953, 2), (954, 0), (958, 1), (971, 3), (959, 9), (967, 7), (969, 8), (975, 6), (971, 4), (962, 5)]
# ########################################################
# smallest = 953, chunk_idx =2
# heappop: [(954, 0), (959, 9), (958, 1), (971, 3), (962, 5), (967, 7), (969, 8), (975, 6), (971, 4)]
# heappush: [(953, 2), (954, 0), (958, 1), (971, 3), (959, 9), (967, 7), (969, 8), (975, 6), (971, 4), (962, 5)]
# ########################################################
# smallest = 953, chunk_idx =2
# heappop: [(954, 0), (959, 9), (958, 1), (971, 3), (962, 5), (967, 7), (969, 8), (975, 6), (971, 4)]
# heappush: [(954, 0), (956, 2), (958, 1), (971, 3), (959, 9), (967, 7), (969, 8), (975, 6), (971, 4), (962, 5)]
# ########################################################
# smallest = 954, chunk_idx =0
# heappop: [(956, 2), (959, 9), (958, 1), (971, 3), (962, 5), (967, 7), (969, 8), (975, 6), (971, 4)]
# heappush: [(956, 2), (959, 9), (958, 1), (971, 3), (962, 5), (967, 7), (969, 8), (975, 6), (971, 4), (971, 0)]
# ########################################################
# smallest = 956, chunk_idx =2
# heappop: [(958, 1), (959, 9), (967, 7), (971, 3), (962, 5), (971, 0), (969, 8), (975, 6), (971, 4)]
# heappush: [(957, 2), (958, 1), (967, 7), (971, 3), (959, 9), (971, 0), (969, 8), (975, 6), (971, 4), (962, 5)]
# ########################################################
# smallest = 957, chunk_idx =2
# heappop: [(958, 1), (959, 9), (967, 7), (971, 3), (962, 5), (971, 0), (969, 8), (975, 6), (971, 4)]
# heappush: [(958, 1), (959, 9), (967, 7), (971, 3), (962, 2), (971, 0), (969, 8), (975, 6), (971, 4), (962, 5)]
# ########################################################
# smallest = 958, chunk_idx =1
# heappop: [(959, 9), (962, 2), (967, 7), (971, 3), (962, 5), (971, 0), (969, 8), (975, 6), (971, 4)]
# heappush: [(959, 9), (962, 2), (967, 7), (971, 3), (962, 5), (971, 0), (969, 8), (975, 6), (971, 4), (967, 1)]
# ########################################################
# smallest = 959, chunk_idx =9
# heappop: [(962, 2), (962, 5), (967, 7), (971, 3), (967, 1), (971, 0), (969, 8), (975, 6), (971, 4)]
# heappush: [(962, 2), (962, 5), (967, 7), (971, 3), (963, 9), (971, 0), (969, 8), (975, 6), (971, 4), (967, 1)]
# ########################################################
# smallest = 962, chunk_idx =2
# heappop: [(962, 5), (963, 9), (967, 7), (971, 3), (967, 1), (971, 0), (969, 8), (975, 6), (971, 4)]
# heappush: [(962, 5), (963, 9), (967, 7), (971, 3), (967, 1), (971, 0), (969, 8), (975, 6), (971, 4), (967, 2)]
# ########################################################
# smallest = 962, chunk_idx =5
# heappop: [(963, 9), (967, 1), (967, 7), (971, 3), (967, 2), (971, 0), (969, 8), (975, 6), (971, 4)]
# heappush: [(963, 9), (967, 1), (967, 7), (971, 3), (967, 2), (971, 0), (969, 8), (975, 6), (971, 4), (969, 5)]
# ########################################################
# smallest = 963, chunk_idx =9
# heappop: [(967, 1), (967, 2), (967, 7), (971, 3), (969, 5), (971, 0), (969, 8), (975, 6), (971, 4)]
# heappush: [(967, 1), (967, 2), (967, 7), (971, 3), (969, 5), (971, 0), (969, 8), (975, 6), (971, 4), (996, 9)]
# ########################################################
# smallest = 967, chunk_idx =1
# heappop: [(967, 2), (969, 5), (967, 7), (971, 3), (996, 9), (971, 0), (969, 8), (975, 6), (971, 4)]
# heappush: [(967, 2), (968, 1), (967, 7), (971, 3), (969, 5), (971, 0), (969, 8), (975, 6), (971, 4), (996, 9)]
# ########################################################
# smallest = 967, chunk_idx =2
# heappop: [(967, 7), (968, 1), (969, 8), (971, 3), (969, 5), (971, 0), (996, 9), (975, 6), (971, 4)]
# heappush: [(967, 7), (968, 1), (969, 8), (971, 3), (969, 5), (971, 0), (996, 9), (975, 6), (971, 4), (981, 2)]
# ########################################################
# smallest = 967, chunk_idx =7
# heappop: [(968, 1), (969, 5), (969, 8), (971, 3), (981, 2), (971, 0), (996, 9), (975, 6), (971, 4)]
# heappush: [(968, 1), (969, 5), (969, 8), (971, 3), (976, 7), (971, 0), (996, 9), (975, 6), (971, 4), (981, 2)]
# ########################################################
# smallest = 968, chunk_idx =1
# heappop: [(969, 5), (971, 3), (969, 8), (971, 4), (976, 7), (971, 0), (996, 9), (975, 6), (981, 2)]
# heappush: [(969, 5), (971, 1), (969, 8), (971, 4), (971, 3), (971, 0), (996, 9), (975, 6), (981, 2), (976, 7)]
# ########################################################
# smallest = 969, chunk_idx =5
# heappop: [(969, 8), (971, 1), (971, 0), (971, 4), (971, 3), (976, 7), (996, 9), (975, 6), (981, 2)]
# heappush: [(969, 8), (971, 1), (971, 0), (971, 4), (971, 3), (976, 7), (996, 9), (975, 6), (981, 2), (979, 5)]
# ########################################################
# smallest = 969, chunk_idx =8
# heappop: [(971, 0), (971, 1), (976, 7), (971, 4), (971, 3), (979, 5), (996, 9), (975, 6), (981, 2)]
# heappush: [(971, 0), (971, 1), (976, 7), (971, 4), (971, 3), (979, 5), (996, 9), (975, 6), (981, 2), (973, 8)]
# ########################################################
# smallest = 971, chunk_idx =0
# heappop: [(971, 1), (971, 3), (976, 7), (971, 4), (973, 8), (979, 5), (996, 9), (975, 6), (981, 2)]
# heappush: [(971, 1), (971, 3), (976, 7), (971, 4), (973, 8), (979, 5), (996, 9), (975, 6), (981, 2), (977, 0)]
# ########################################################
# smallest = 971, chunk_idx =1
# heappop: [(971, 3), (971, 4), (976, 7), (975, 6), (973, 8), (979, 5), (996, 9), (977, 0), (981, 2)]
# heappush: [(971, 3), (971, 4), (976, 7), (975, 6), (972, 1), (979, 5), (996, 9), (977, 0), (981, 2), (973, 8)]
# ########################################################
# smallest = 971, chunk_idx =3
# heappop: [(971, 4), (972, 1), (976, 7), (975, 6), (973, 8), (979, 5), (996, 9), (977, 0), (981, 2)]
# heappush: [(971, 4), (972, 1), (976, 7), (975, 6), (973, 8), (979, 5), (996, 9), (977, 0), (981, 2), (975, 3)]
# ########################################################
# smallest = 971, chunk_idx =4
# heappop: [(972, 1), (973, 8), (976, 7), (975, 6), (975, 3), (979, 5), (996, 9), (977, 0), (981, 2)]
# ########################################################
# smallest = 972, chunk_idx =1
# heappop: [(973, 8), (975, 3), (976, 7), (975, 6), (981, 2), (979, 5), (996, 9), (977, 0)]
# heappush: [(973, 8), (975, 3), (976, 7), (975, 6), (981, 2), (979, 5), (996, 9), (977, 0), (981, 1)]
# ########################################################
# smallest = 973, chunk_idx =8
# heappop: [(975, 3), (975, 6), (976, 7), (977, 0), (981, 2), (979, 5), (996, 9), (981, 1)]
# heappush: [(975, 3), (975, 6), (976, 7), (975, 8), (981, 2), (979, 5), (996, 9), (981, 1), (977, 0)]
# ########################################################
# smallest = 975, chunk_idx =3
# heappop: [(975, 6), (975, 8), (976, 7), (977, 0), (981, 2), (979, 5), (996, 9), (981, 1)]
# heappush: [(975, 6), (975, 8), (976, 7), (977, 0), (981, 2), (979, 5), (996, 9), (981, 1), (977, 3)]
# ########################################################
# smallest = 975, chunk_idx =6
# heappop: [(975, 8), (977, 0), (976, 7), (977, 3), (981, 2), (979, 5), (996, 9), (981, 1)]
# heappush: [(975, 8), (977, 0), (976, 7), (977, 3), (981, 2), (979, 5), (996, 9), (981, 1), (990, 6)]
# ########################################################
# smallest = 975, chunk_idx =8
# heappop: [(976, 7), (977, 0), (979, 5), (977, 3), (981, 2), (990, 6), (996, 9), (981, 1)]
# heappush: [(976, 7), (976, 8), (979, 5), (977, 0), (981, 2), (990, 6), (996, 9), (981, 1), (977, 3)]
# ########################################################
# smallest = 976, chunk_idx =7
# heappop: [(976, 8), (977, 0), (979, 5), (977, 3), (981, 2), (990, 6), (996, 9), (981, 1)]
# heappush: [(976, 8), (977, 0), (979, 5), (977, 3), (981, 2), (990, 6), (996, 9), (981, 1), (977, 7)]
# ########################################################
# smallest = 976, chunk_idx =8
# heappop: [(977, 0), (977, 3), (979, 5), (977, 7), (981, 2), (990, 6), (996, 9), (981, 1)]
# heappush: [(977, 0), (977, 3), (979, 5), (977, 7), (981, 2), (990, 6), (996, 9), (981, 1), (990, 8)]
# ########################################################
# smallest = 977, chunk_idx =0
# heappop: [(977, 3), (977, 7), (979, 5), (981, 1), (981, 2), (990, 6), (996, 9), (990, 8)]
# heappush: [(977, 3), (977, 7), (979, 5), (981, 1), (981, 2), (990, 6), (996, 9), (990, 8), (987, 0)]
# ########################################################
# smallest = 977, chunk_idx =3
# heappop: [(977, 7), (981, 1), (979, 5), (987, 0), (981, 2), (990, 6), (996, 9), (990, 8)]
# heappush: [(977, 7), (981, 1), (979, 5), (987, 0), (981, 2), (990, 6), (996, 9), (990, 8), (992, 3)]
# ########################################################
# smallest = 977, chunk_idx =7
# heappop: [(979, 5), (981, 1), (990, 6), (987, 0), (981, 2), (992, 3), (996, 9), (990, 8)]
# heappush: [(979, 5), (981, 1), (990, 6), (983, 7), (981, 2), (992, 3), (996, 9), (990, 8), (987, 0)]
# ########################################################
# smallest = 979, chunk_idx =5
# heappop: [(981, 1), (981, 2), (990, 6), (983, 7), (987, 0), (992, 3), (996, 9), (990, 8)]
# heappush: [(981, 1), (981, 2), (990, 6), (983, 7), (987, 0), (992, 3), (996, 9), (990, 8), (986, 5)]
# ########################################################
# smallest = 981, chunk_idx =1
# heappop: [(981, 2), (983, 7), (990, 6), (986, 5), (987, 0), (992, 3), (996, 9), (990, 8)]
# heappush: [(981, 2), (983, 7), (990, 6), (986, 1), (987, 0), (992, 3), (996, 9), (990, 8), (986, 5)]
# ########################################################
# smallest = 981, chunk_idx =2
# heappop: [(983, 7), (986, 1), (990, 6), (986, 5), (987, 0), (992, 3), (996, 9), (990, 8)]
# ########################################################
# smallest = 983, chunk_idx =7
# heappop: [(986, 1), (986, 5), (990, 6), (990, 8), (987, 0), (992, 3), (996, 9)]
# ########################################################
# smallest = 986, chunk_idx =1
# heappop: [(986, 5), (987, 0), (990, 6), (990, 8), (996, 9), (992, 3)]
# heappush: [(986, 5), (987, 0), (989, 1), (990, 8), (996, 9), (992, 3), (990, 6)]
# ########################################################
# smallest = 986, chunk_idx =5
# heappop: [(987, 0), (990, 6), (989, 1), (990, 8), (996, 9), (992, 3)]
# heappush: [(986, 5), (990, 6), (987, 0), (990, 8), (996, 9), (992, 3), (989, 1)]
# ########################################################
# smallest = 986, chunk_idx =5
# heappop: [(987, 0), (990, 6), (989, 1), (990, 8), (996, 9), (992, 3)]
# heappush: [(987, 0), (990, 6), (989, 1), (990, 8), (996, 9), (992, 3), (998, 5)]
# ########################################################
# smallest = 987, chunk_idx =0
# heappop: [(989, 1), (990, 6), (992, 3), (990, 8), (996, 9), (998, 5)]
# heappush: [(989, 1), (990, 6), (992, 3), (990, 8), (996, 9), (998, 5), (997, 0)]
# ########################################################
# smallest = 989, chunk_idx =1
# heappop: [(990, 6), (990, 8), (992, 3), (997, 0), (996, 9), (998, 5)]
# heappush: [(990, 6), (990, 8), (992, 3), (997, 0), (996, 9), (998, 5), (1000, 1)]
# ########################################################
# smallest = 990, chunk_idx =6
# heappop: [(990, 8), (996, 9), (992, 3), (997, 0), (1000, 1), (998, 5)]
# heappush: [(990, 8), (996, 9), (992, 3), (997, 0), (1000, 1), (998, 5), (999, 6)]
# ########################################################
# smallest = 990, chunk_idx =8
# heappop: [(992, 3), (996, 9), (998, 5), (997, 0), (1000, 1), (999, 6)]
# heappush: [(992, 3), (996, 9), (992, 8), (997, 0), (1000, 1), (999, 6), (998, 5)]
# ########################################################
# smallest = 992, chunk_idx =3
# heappop: [(992, 8), (996, 9), (998, 5), (997, 0), (1000, 1), (999, 6)]
# heappush: [(992, 8), (996, 9), (994, 3), (997, 0), (1000, 1), (999, 6), (998, 5)]
# ########################################################
# smallest = 992, chunk_idx =8
# heappop: [(994, 3), (996, 9), (998, 5), (997, 0), (1000, 1), (999, 6)]
# heappush: [(994, 3), (996, 9), (995, 8), (997, 0), (1000, 1), (999, 6), (998, 5)]
# ########################################################
# smallest = 994, chunk_idx =3
# heappop: [(995, 8), (996, 9), (998, 5), (997, 0), (1000, 1), (999, 6)]
# ########################################################
# smallest = 995, chunk_idx =8
# heappop: [(996, 9), (997, 0), (998, 5), (999, 6), (1000, 1)]
# ########################################################
# smallest = 996, chunk_idx =9
# heappop: [(997, 0), (999, 6), (998, 5), (1000, 1)]
# ########################################################
# smallest = 997, chunk_idx =0
# heappop: [(998, 5), (999, 6), (1000, 1)]
# ########################################################
# smallest = 998, chunk_idx =5
# heappop: [(999, 6), (1000, 1)]
# heappush: [(998, 5), (1000, 1), (999, 6)]
# ########################################################
# smallest = 998, chunk_idx =5
# heappop: [(999, 6), (1000, 1)]
# ########################################################
# smallest = 999, chunk_idx =6
# heappop: [(1000, 1)]
# ########################################################
# smallest = 1000, chunk_idx =1
# heappop: []

# %%
import heapq

# Initial list
lst = [4, 3, 7, 1, 9, 2]

# Turn the list into a min-heap
heapq.heapify(lst)

print(lst)
# Out:
# [1, 3, 2, 4, 9, 7]

# %%
import heapq

# Create a min-heap
heap = [3, 1, 4, 1, 5, 9, 2]

# Retrieve and remove the first element
smallest = heapq.heappop(heap)

print(f"The first element is: {smallest}")
print(f"The updated heap is: {heap}")
# Out:
# The smallest element is: 3
# The updated heap is: [1, 1, 4, 2, 5, 9]

# %% [markdown]
# -----

# %%
import random

def generate_dummy_dataset(filename):
    country_name = ['country_name', 'USA', 'Canada', 'Germany', 'France', 'UK']
    year = ['year', 2020, 2019, 2018, 2021, 2017]
    with open(filename, 'w') as file:
        for idx, ele in enumerate(country_name):
            file.write(str(country_name[idx]) + ',' + str(year[idx]) + '\n')

generate_dummy_dataset('dummy_data.csv')

# %% [markdown]
# ----

# %%
import csv
import shutil
import random
import tempfile
import pandas as pd

# %%
# Generate a dummy dataset with 100 rows
data = []

for _ in range(100):
    country = random.choice(["CountryA", "CountryB", "CountryC"])
    year = random.randint(1900, 2023)
    data.append([country, year])

# Shuffle the data to make it unordered
random.shuffle(data)

# Write the data to a CSV file
with open('dummy_data.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    # writer.writerow(['country_name', 'year'])
    writer.writerows(data)

# %%
def sort_chunks(chunk_paths, output_path):
    # Read chunks, sort, and write to temporary files
    sorted_chunk_paths = []
    for chunk_path in chunk_paths:
        with open(chunk_path, 'r') as chunk_file:
            chunk = list(csv.reader(chunk_file))
            chunk.sort(key=lambda x: (x[0], int(x[1])))

            sorted_chunk_path = tempfile.mktemp()
            with open(sorted_chunk_path, 'w', newline='') as sorted_chunk_file:
                writer = csv.writer(sorted_chunk_file)
                writer.writerows(chunk)

            sorted_chunk_paths.append(sorted_chunk_path)

    # Merge sorted chunks
    with open(output_path, 'w', newline='') as output_file:
        writer = csv.writer(output_file)
        readers = [csv.reader(open(sorted_chunk_path, 'r')) for sorted_chunk_path in sorted_chunk_paths]
        merged = heapq.merge(*readers, key=lambda x: (x[0], int(x[1])))
        writer.writerows(merged)

    # Clean up temporary files
    for sorted_chunk_path in sorted_chunk_paths:
        os.remove(sorted_chunk_path)

# %%
input_path = 'dummy_data.csv'
output_path = 'sorted_data.csv' 
chunk_size=9 # chunk_size=10, but the chunk list stores 11 rows, so I ma gonna make chunk_size=9.

# Step 1: Read the input data and divide into chunks
chunk_paths = []
with open(input_path, 'r') as input_file:
    reader = csv.reader(input_file)
    header = next(reader)
    # print(f"{header = }")
    chunk = [header]
    count = 0
    
    print("############ 1 ############ ")
    for row in reader:
        # print(f"{row = }")
        chunk.append(row)
        print(f"{chunk = }")
        count += 1
        '''
        chunk_size=10, but the chunk list stores 11 rows, so I am gonna make chunk_size=9.
        '''
        if count == chunk_size:
            chunk_path = tempfile.mktemp()
            print(f"{chunk_path = }")
            with open(chunk_path, 'w', newline='') as chunk_file:
                writer = csv.writer(chunk_file)
                writer.writerows(chunk)
            chunk_paths.append(chunk_path)
            print("############ 2 ############ ")
            # print(f"{header = }")
            # chunk = [header]
            chunk = []
            print(f"{chunk = }")
            count = 0
    print("########################## ")
        
# Step 2: Sort and merge chunks
sort_chunks(chunk_paths, output_path)

# Clean up temporary chunk files
for chunk_path in chunk_paths:
    os.remove(chunk_path)
# Out:
# ############ 1 ############
# chunk = [['CountryA', '1948'], ['CountryC', '1975']]
# chunk = [['CountryA', '1948'], ['CountryC', '1975'], ['CountryC', '1972']]
# chunk = [['CountryA', '1948'], ['CountryC', '1975'], ['CountryC', '1972'], ['CountryB', '2001']]
# chunk = [['CountryA', '1948'], ['CountryC', '1975'], ['CountryC', '1972'], ['CountryB', '2001'], ['CountryB', '1907']]
# chunk = [['CountryA', '1948'], ['CountryC', '1975'], ['CountryC', '1972'], ['CountryB', '2001'], ['CountryB', '1907'], ['CountryC', '1909']]
# chunk = [['CountryA', '1948'], ['CountryC', '1975'], ['CountryC', '1972'], ['CountryB', '2001'], ['CountryB', '1907'], ['CountryC', '1909'], ['CountryA', '1990']]
# chunk = [['CountryA', '1948'], ['CountryC', '1975'], ['CountryC', '1972'], ['CountryB', '2001'], ['CountryB', '1907'], ['CountryC', '1909'], ['CountryA', '1990'], ['CountryA', '1915']]
# chunk = [['CountryA', '1948'], ['CountryC', '1975'], ['CountryC', '1972'], ['CountryB', '2001'], ['CountryB', '1907'], ['CountryC', '1909'], ['CountryA', '1990'], ['CountryA', '1915'], ['CountryC', '1923']]
# chunk = [['CountryA', '1948'], ['CountryC', '1975'], ['CountryC', '1972'], ['CountryB', '2001'], ['CountryB', '1907'], ['CountryC', '1909'], ['CountryA', '1990'], ['CountryA', '1915'], ['CountryC', '1923'], ['CountryA', '1968']]
# chunk_path = '/tmp/tmpetl_a7sf'
# ############ 2 ############
# chunk = []
# chunk = [['CountryB', '1988']]
# chunk = [['CountryB', '1988'], ['CountryC', '1976']]
# chunk = [['CountryB', '1988'], ['CountryC', '1976'], ['CountryC', '2018']]
# chunk = [['CountryB', '1988'], ['CountryC', '1976'], ['CountryC', '2018'], ['CountryC', '1900']]
# chunk = [['CountryB', '1988'], ['CountryC', '1976'], ['CountryC', '2018'], ['CountryC', '1900'], ['CountryB', '1948']]
# chunk = [['CountryB', '1988'], ['CountryC', '1976'], ['CountryC', '2018'], ['CountryC', '1900'], ['CountryB', '1948'], ['CountryC', '2000']]
# chunk = [['CountryB', '1988'], ['CountryC', '1976'], ['CountryC', '2018'], ['CountryC', '1900'], ['CountryB', '1948'], ['CountryC', '2000'], ['CountryB', '1917']]
# chunk = [['CountryB', '1988'], ['CountryC', '1976'], ['CountryC', '2018'], ['CountryC', '1900'], ['CountryB', '1948'], ['CountryC', '2000'], ['CountryB', '1917'], ['CountryB', '1915']]
# chunk = [['CountryB', '1988'], ['CountryC', '1976'], ['CountryC', '2018'], ['CountryC', '1900'], ['CountryB', '1948'], ['CountryC', '2000'], ['CountryB', '1917'], ['CountryB', '1915'], ['CountryB', '1948']]
# chunk_path = '/tmp/tmpucl7vc1c'
# ############ 2 ############
# chunk = []
# chunk = [['CountryB', '1994']]
# chunk = [['CountryB', '1994'], ['CountryA', '2004']]
# chunk = [['CountryB', '1994'], ['CountryA', '2004'], ['CountryB', '2010']]
# chunk = [['CountryB', '1994'], ['CountryA', '2004'], ['CountryB', '2010'], ['CountryA', '1945']]
# chunk = [['CountryB', '1994'], ['CountryA', '2004'], ['CountryB', '2010'], ['CountryA', '1945'], ['CountryC', '1994']]
# chunk = [['CountryB', '1994'], ['CountryA', '2004'], ['CountryB', '2010'], ['CountryA', '1945'], ['CountryC', '1994'], ['CountryA', '1987']]
# chunk = [['CountryB', '1994'], ['CountryA', '2004'], ['CountryB', '2010'], ['CountryA', '1945'], ['CountryC', '1994'], ['CountryA', '1987'], ['CountryC', '2003']]
# chunk = [['CountryB', '1994'], ['CountryA', '2004'], ['CountryB', '2010'], ['CountryA', '1945'], ['CountryC', '1994'], ['CountryA', '1987'], ['CountryC', '2003'], ['CountryC', '1970']]
# chunk = [['CountryB', '1994'], ['CountryA', '2004'], ['CountryB', '2010'], ['CountryA', '1945'], ['CountryC', '1994'], ['CountryA', '1987'], ['CountryC', '2003'], ['CountryC', '1970'], ['CountryB', '1968']]
# chunk_path = '/tmp/tmpl8xqr7d5'
# ############ 2 ############
# chunk = []
# chunk = [['CountryB', '1987']]
# chunk = [['CountryB', '1987'], ['CountryC', '1958']]
# chunk = [['CountryB', '1987'], ['CountryC', '1958'], ['CountryC', '1983']]
# chunk = [['CountryB', '1987'], ['CountryC', '1958'], ['CountryC', '1983'], ['CountryB', '1968']]
# chunk = [['CountryB', '1987'], ['CountryC', '1958'], ['CountryC', '1983'], ['CountryB', '1968'], ['CountryC', '2022']]
# chunk = [['CountryB', '1987'], ['CountryC', '1958'], ['CountryC', '1983'], ['CountryB', '1968'], ['CountryC', '2022'], ['CountryB', '1959']]
# chunk = [['CountryB', '1987'], ['CountryC', '1958'], ['CountryC', '1983'], ['CountryB', '1968'], ['CountryC', '2022'], ['CountryB', '1959'], ['CountryB', '2014']]
# chunk = [['CountryB', '1987'], ['CountryC', '1958'], ['CountryC', '1983'], ['CountryB', '1968'], ['CountryC', '2022'], ['CountryB', '1959'], ['CountryB', '2014'], ['CountryC', '1925']]
# chunk = [['CountryB', '1987'], ['CountryC', '1958'], ['CountryC', '1983'], ['CountryB', '1968'], ['CountryC', '2022'], ['CountryB', '1959'], ['CountryB', '2014'], ['CountryC', '1925'], ['CountryA', '1930']]
# chunk_path = '/tmp/tmpomhnf466'
# ############ 2 ############
# chunk = []
# chunk = [['CountryC', '1928']]
# chunk = [['CountryC', '1928'], ['CountryB', '1963']]
# chunk = [['CountryC', '1928'], ['CountryB', '1963'], ['CountryA', '2006']]
# chunk = [['CountryC', '1928'], ['CountryB', '1963'], ['CountryA', '2006'], ['CountryA', '1965']]
# chunk = [['CountryC', '1928'], ['CountryB', '1963'], ['CountryA', '2006'], ['CountryA', '1965'], ['CountryB', '1906']]
# chunk = [['CountryC', '1928'], ['CountryB', '1963'], ['CountryA', '2006'], ['CountryA', '1965'], ['CountryB', '1906'], ['CountryC', '1921']]
# chunk = [['CountryC', '1928'], ['CountryB', '1963'], ['CountryA', '2006'], ['CountryA', '1965'], ['CountryB', '1906'], ['CountryC', '1921'], ['CountryB', '1978']]
# chunk = [['CountryC', '1928'], ['CountryB', '1963'], ['CountryA', '2006'], ['CountryA', '1965'], ['CountryB', '1906'], ['CountryC', '1921'], ['CountryB', '1978'], ['CountryA', '1920']]
# chunk = [['CountryC', '1928'], ['CountryB', '1963'], ['CountryA', '2006'], ['CountryA', '1965'], ['CountryB', '1906'], ['CountryC', '1921'], ['CountryB', '1978'], ['CountryA', '1920'], ['CountryA', '1920']]
# chunk_path = '/tmp/tmpilyemq1p'
# ############ 2 ############
# chunk = []
# chunk = [['CountryC', '1981']]
# chunk = [['CountryC', '1981'], ['CountryA', '1931']]
# chunk = [['CountryC', '1981'], ['CountryA', '1931'], ['CountryA', '1997']]
# chunk = [['CountryC', '1981'], ['CountryA', '1931'], ['CountryA', '1997'], ['CountryC', '2004']]
# chunk = [['CountryC', '1981'], ['CountryA', '1931'], ['CountryA', '1997'], ['CountryC', '2004'], ['CountryA', '1931']]
# chunk = [['CountryC', '1981'], ['CountryA', '1931'], ['CountryA', '1997'], ['CountryC', '2004'], ['CountryA', '1931'], ['CountryA', '2002']]
# chunk = [['CountryC', '1981'], ['CountryA', '1931'], ['CountryA', '1997'], ['CountryC', '2004'], ['CountryA', '1931'], ['CountryA', '2002'], ['CountryB', '1944']]
# chunk = [['CountryC', '1981'], ['CountryA', '1931'], ['CountryA', '1997'], ['CountryC', '2004'], ['CountryA', '1931'], ['CountryA', '2002'], ['CountryB', '1944'], ['CountryA', '1989']]
# chunk = [['CountryC', '1981'], ['CountryA', '1931'], ['CountryA', '1997'], ['CountryC', '2004'], ['CountryA', '1931'], ['CountryA', '2002'], ['CountryB', '1944'], ['CountryA', '1989'], ['CountryC', '1983']]
# chunk_path = '/tmp/tmpjh8ar7cn'
# ############ 2 ############
# chunk = []
# chunk = [['CountryB', '2012']]
# chunk = [['CountryB', '2012'], ['CountryA', '2022']]
# chunk = [['CountryB', '2012'], ['CountryA', '2022'], ['CountryA', '2022']]
# chunk = [['CountryB', '2012'], ['CountryA', '2022'], ['CountryA', '2022'], ['CountryB', '1904']]
# chunk = [['CountryB', '2012'], ['CountryA', '2022'], ['CountryA', '2022'], ['CountryB', '1904'], ['CountryC', '1940']]
# chunk = [['CountryB', '2012'], ['CountryA', '2022'], ['CountryA', '2022'], ['CountryB', '1904'], ['CountryC', '1940'], ['CountryC', '2020']]
# chunk = [['CountryB', '2012'], ['CountryA', '2022'], ['CountryA', '2022'], ['CountryB', '1904'], ['CountryC', '1940'], ['CountryC', '2020'], ['CountryC', '1970']]
# chunk = [['CountryB', '2012'], ['CountryA', '2022'], ['CountryA', '2022'], ['CountryB', '1904'], ['CountryC', '1940'], ['CountryC', '2020'], ['CountryC', '1970'], ['CountryC', '1928']]
# chunk = [['CountryB', '2012'], ['CountryA', '2022'], ['CountryA', '2022'], ['CountryB', '1904'], ['CountryC', '1940'], ['CountryC', '2020'], ['CountryC', '1970'], ['CountryC', '1928'], ['CountryB', '1988']]
# chunk_path = '/tmp/tmp_dkopj6l'
# ############ 2 ############
# chunk = []
# chunk = [['CountryA', '2023']]
# chunk = [['CountryA', '2023'], ['CountryB', '1969']]
# chunk = [['CountryA', '2023'], ['CountryB', '1969'], ['CountryA', '1905']]
# chunk = [['CountryA', '2023'], ['CountryB', '1969'], ['CountryA', '1905'], ['CountryA', '1993']]
# chunk = [['CountryA', '2023'], ['CountryB', '1969'], ['CountryA', '1905'], ['CountryA', '1993'], ['CountryC', '1950']]
# chunk = [['CountryA', '2023'], ['CountryB', '1969'], ['CountryA', '1905'], ['CountryA', '1993'], ['CountryC', '1950'], ['CountryC', '1958']]
# chunk = [['CountryA', '2023'], ['CountryB', '1969'], ['CountryA', '1905'], ['CountryA', '1993'], ['CountryC', '1950'], ['CountryC', '1958'], ['CountryC', '1951']]
# chunk = [['CountryA', '2023'], ['CountryB', '1969'], ['CountryA', '1905'], ['CountryA', '1993'], ['CountryC', '1950'], ['CountryC', '1958'], ['CountryC', '1951'], ['CountryC', '1988']]
# chunk = [['CountryA', '2023'], ['CountryB', '1969'], ['CountryA', '1905'], ['CountryA', '1993'], ['CountryC', '1950'], ['CountryC', '1958'], ['CountryC', '1951'], ['CountryC', '1988'], ['CountryA', '2012']]
# chunk_path = '/tmp/tmppe6h3p4_'
# ############ 2 ############
# chunk = []
# chunk = [['CountryB', '1947']]
# chunk = [['CountryB', '1947'], ['CountryB', '1936']]
# chunk = [['CountryB', '1947'], ['CountryB', '1936'], ['CountryB', '2009']]
# chunk = [['CountryB', '1947'], ['CountryB', '1936'], ['CountryB', '2009'], ['CountryA', '1929']]
# chunk = [['CountryB', '1947'], ['CountryB', '1936'], ['CountryB', '2009'], ['CountryA', '1929'], ['CountryC', '1979']]
# chunk = [['CountryB', '1947'], ['CountryB', '1936'], ['CountryB', '2009'], ['CountryA', '1929'], ['CountryC', '1979'], ['CountryB', '1901']]
# chunk = [['CountryB', '1947'], ['CountryB', '1936'], ['CountryB', '2009'], ['CountryA', '1929'], ['CountryC', '1979'], ['CountryB', '1901'], ['CountryB', '1961']]
# chunk = [['CountryB', '1947'], ['CountryB', '1936'], ['CountryB', '2009'], ['CountryA', '1929'], ['CountryC', '1979'], ['CountryB', '1901'], ['CountryB', '1961'], ['CountryA', '1943']]
# chunk = [['CountryB', '1947'], ['CountryB', '1936'], ['CountryB', '2009'], ['CountryA', '1929'], ['CountryC', '1979'], ['CountryB', '1901'], ['CountryB', '1961'], ['CountryA', '1943'], ['CountryC', '1981']]
# chunk_path = '/tmp/tmph9_6q3cm'
# ############ 2 ############
# chunk = []
# chunk = [['CountryB', '1973']]
# chunk = [['CountryB', '1973'], ['CountryC', '1954']]
# chunk = [['CountryB', '1973'], ['CountryC', '1954'], ['CountryB', '1991']]
# chunk = [['CountryB', '1973'], ['CountryC', '1954'], ['CountryB', '1991'], ['CountryA', '1929']]
# chunk = [['CountryB', '1973'], ['CountryC', '1954'], ['CountryB', '1991'], ['CountryA', '1929'], ['CountryA', '1973']]
# chunk = [['CountryB', '1973'], ['CountryC', '1954'], ['CountryB', '1991'], ['CountryA', '1929'], ['CountryA', '1973'], ['CountryB', '2022']]
# chunk = [['CountryB', '1973'], ['CountryC', '1954'], ['CountryB', '1991'], ['CountryA', '1929'], ['CountryA', '1973'], ['CountryB', '2022'], ['CountryB', '1966']]
# chunk = [['CountryB', '1973'], ['CountryC', '1954'], ['CountryB', '1991'], ['CountryA', '1929'], ['CountryA', '1973'], ['CountryB', '2022'], ['CountryB', '1966'], ['CountryB', '2011']]
# chunk = [['CountryB', '1973'], ['CountryC', '1954'], ['CountryB', '1991'], ['CountryA', '1929'], ['CountryA', '1973'], ['CountryB', '2022'], ['CountryB', '1966'], ['CountryB', '2011'], ['CountryA', '1945']]
# chunk_path = '/tmp/tmpijm253h1'
# ############ 2 ############
# chunk = []
# chunk = [['CountryA', '1922']]
# chunk = [['CountryA', '1922'], ['CountryB', '2014']]
# chunk = [['CountryA', '1922'], ['CountryB', '2014'], ['CountryB', '1975']]
# chunk = [['CountryA', '1922'], ['CountryB', '2014'], ['CountryB', '1975'], ['CountryB', '1953']]
# chunk = [['CountryA', '1922'], ['CountryB', '2014'], ['CountryB', '1975'], ['CountryB', '1953'], ['CountryB', '1928']]
# chunk = [['CountryA', '1922'], ['CountryB', '2014'], ['CountryB', '1975'], ['CountryB', '1953'], ['CountryB', '1928'], ['CountryB', '1927']]
# chunk = [['CountryA', '1922'], ['CountryB', '2014'], ['CountryB', '1975'], ['CountryB', '1953'], ['CountryB', '1928'], ['CountryB', '1927'], ['CountryB', '2003']]
# chunk = [['CountryA', '1922'], ['CountryB', '2014'], ['CountryB', '1975'], ['CountryB', '1953'], ['CountryB', '1928'], ['CountryB', '1927'], ['CountryB', '2003'], ['CountryC', '1914']]
# chunk = [['CountryA', '1922'], ['CountryB', '2014'], ['CountryB', '1975'], ['CountryB', '1953'], ['CountryB', '1928'], ['CountryB', '1927'], ['CountryB', '2003'], ['CountryC', '1914'], ['CountryA', '2012']]
# chunk_path = '/tmp/tmphshysy08'
# ############ 2 ############
# chunk = []
# ##########################

# %%
# Load sorted data into a pandas dataframe
sorted_df = pd.read_csv('sorted_data.csv')
print(sorted_df)
# Out:
#     CountryA  1905
# 0   CountryA  1915
# 1   CountryA  1920
# 2   CountryA  1920
# 3   CountryA  1922
# 4   CountryA  1929
# ..       ...   ...
# 94  CountryC  2003
# 95  CountryC  2004
# 96  CountryC  2018
# 97  CountryC  2020
# 98  CountryC  2022
#
# [99 rows x 2 columns]

# %% [markdown]
# ----

# %% [markdown]
# ## Try a much more realistic dataset like ours

# %%
import csv
import shutil
import random
import tempfile
import pandas as pd

def sort_chunks(chunk_paths, output_path):
    # Read chunks, sort, and write to temporary files
    sorted_chunk_paths = []
    for chunk_path in chunk_paths:
        with open(chunk_path, 'r') as chunk_file:
            chunk = list(csv.reader(chunk_file))
            chunk.sort(key=lambda x: (x[0], int(x[1])))

            sorted_chunk_path = tempfile.mktemp()
            with open(sorted_chunk_path, 'w', newline='') as sorted_chunk_file:
                writer = csv.writer(sorted_chunk_file)
                writer.writerows(chunk)

            sorted_chunk_paths.append(sorted_chunk_path)

    # Merge sorted chunks
    with open(output_path, 'w', newline='') as output_file:
        writer = csv.writer(output_file)
        readers = [csv.reader(open(sorted_chunk_path, 'r')) for sorted_chunk_path in sorted_chunk_paths]
        merged = heapq.merge(*readers, key=lambda x: (x[0], int(x[1])))
        writer.writerows(merged)

    # Clean up temporary files
    for sorted_chunk_path in sorted_chunk_paths:
        os.remove(sorted_chunk_path)

# %%
input_path = 'sample_preprocessed.csv'
output_path = 'sorted_sample_preprocessed.csv' 
chunk_size=9 # chunk_size=10, but the chunk list stores 11 rows, so I ma gonna make chunk_size=9.

# Step 1: Read the input data and divide into chunks
chunk_paths = []
with open(input_path, 'r') as input_file:
    reader = csv.reader(input_file)
    header = next(reader)
    # print(f"{header = }")
    chunk = [header]
    count = 0
    
    print("############ 1 ############ ")
    for row in reader:
        # print(f"{row = }")
        chunk.append(row)
        print(f"{chunk = }")
        count += 1
        '''
        chunk_size=10, but the chunk list stores 11 rows, so I am gonna make chunk_size=9.
        '''
        if count == chunk_size:
            chunk_path = tempfile.mktemp()
            print(f"{chunk_path = }")
            with open(chunk_path, 'w', newline='') as chunk_file:
                writer = csv.writer(chunk_file)
                writer.writerows(chunk)
            chunk_paths.append(chunk_path)
            print("############ 2 ############ ")
            # print(f"{header = }")
            # chunk = [header]
            chunk = []
            print(f"{chunk = }")
            count = 0
    print("########################## ")
        
# Step 2: Sort and merge chunks
sort_chunks(chunk_paths, output_path)

# Clean up temporary chunk files
for chunk_path in chunk_paths:
    os.remove(chunk_path)
# Out:
# ############ 1 ############
# chunk = [['Albania', '1987', 'male', '15-24 years', 'Generation X', 'low_suicides_range', 'medium_population_range', 'low_income_range', '0-2000'], ['Albania', '2004', 'female', '75+ years', 'Silent', 'low_suicides_range', 'low_population_range', 'low_income_range', '2000-4000']]
# chunk = [['Albania', '1987', 'male', '15-24 years', 'Generation X', 'low_suicides_range', 'medium_population_range', 'low_income_range', '0-2000'], ['Albania', '2004', 'female', '75+ years', 'Silent', 'low_suicides_range', 'low_population_range', 'low_income_range', '2000-4000'], ['Albania', '2004', 'female', '25-34 years', 'Generation X', 'low_suicides_range', 'medium_population_range', 'low_income_range', '2000-4000']]
# chunk = [['Albania', '1987', 'male', '15-24 years', 'Generation X', 'low_suicides_range', 'medium_population_range', 'low_income_range', '0-2000'], ['Albania', '2004', 'female', '75+ years', 'Silent', 'low_suicides_range', 'low_population_range', 'low_income_range', '2000-4000'], ['Albania', '2004', 'female', '25-34 years', 'Generation X', 'low_suicides_range', 'medium_population_range', 'low_income_range', '2000-4000'], ['Argentina', '1990', 'male', '15-24 years', 'Generation X', 'high_suicides_range', 'high_population_range', 'medium_income_range', '4000-6000']]
# chunk = [['Albania', '1987', 'male', '15-24 years', 'Generation X', 'low_suicides_range', 'medium_population_range', 'low_income_range', '0-2000'], ['Albania', '2004', 'female', '75+ years', 'Silent', 'low_suicides_range', 'low_population_range', 'low_income_range', '2000-4000'], ['Albania', '2004', 'female', '25-34 years', 'Generation X', 'low_suicides_range', 'medium_population_range', 'low_income_range', '2000-4000'], ['Argentina', '1990', 'male', '15-24 years', 'Generation X', 'high_suicides_range', 'high_population_range', 'medium_income_range', '4000-6000'], ['Argentina', '1990', 'female', '35-54 years', 'Silent', 'high_suicides_range', 'high_population_range', 'medium_income_range', '4000-6000']]
# chunk = [['Albania', '1987', 'male', '15-24 years', 'Generation X', 'low_suicides_range', 'medium_population_range', 'low_income_range', '0-2000'], ['Albania', '2004', 'female', '75+ years', 'Silent', 'low_suicides_range', 'low_population_range', 'low_income_range', '2000-4000'], ['Albania', '2004', 'female', '25-34 years', 'Generation X', 'low_suicides_range', 'medium_population_range', 'low_income_range', '2000-4000'], ['Argentina', '1990', 'male', '15-24 years', 'Generation X', 'high_suicides_range', 'high_population_range', 'medium_income_range', '4000-6000'], ['Argentina', '1990', 'female', '35-54 years', 'Silent', 'high_suicides_range', 'high_population_range', 'medium_income_range', '4000-6000'], ['Argentina', '1999', 'female', '5-14 years', 'Millenials', 'low_suicides_range', 'high_population_range', 'high_income_range', '8000-10000']]
# chunk = [['Albania', '1987', 'male', '15-24 years', 'Generation X', 'low_suicides_range', 'medium_population_range', 'low_income_range', '0-2000'], ['Albania', '2004', 'female', '75+ years', 'Silent', 'low_suicides_range', 'low_population_range', 'low_income_range', '2000-4000'], ['Albania', '2004', 'female', '25-34 years', 'Generation X', 'low_suicides_range', 'medium_population_range', 'low_income_range', '2000-4000'], ['Argentina', '1990', 'male', '15-24 years', 'Generation X', 'high_suicides_range', 'high_population_range', 'medium_income_range', '4000-6000'], ['Argentina', '1990', 'female', '35-54 years', 'Silent', 'high_suicides_range', 'high_population_range', 'medium_income_range', '4000-6000'], ['Argentina', '1999', 'female', '5-14 years', 'Millenials', 'low_suicides_range', 'high_population_range', 'high_income_range', '8000-10000'], ['Argentina', '2000', 'male', '75+ years', 'G.I. Generation', 'high_suicides_range', 'medium_population_range', 'high_income_range', '8000-10000']]
# chunk = [['Albania', '1987', 'male', '15-24 years', 'Generation X', 'low_suicides_range', 'medium_population_range', 'low_income_range', '0-2000'], ['Albania', '2004', 'female', '75+ years', 'Silent', 'low_suicides_range', 'low_population_range', 'low_income_range', '2000-4000'], ['Albania', '2004', 'female', '25-34 years', 'Generation X', 'low_suicides_range', 'medium_population_range', 'low_income_range', '2000-4000'], ['Argentina', '1990', 'male', '15-24 years', 'Generation X', 'high_suicides_range', 'high_population_range', 'medium_income_range', '4000-6000'], ['Argentina', '1990', 'female', '35-54 years', 'Silent', 'high_suicides_range', 'high_population_range', 'medium_income_range', '4000-6000'], ['Argentina', '1999', 'female', '5-14 years', 'Millenials', 'low_suicides_range', 'high_population_range', 'high_income_range', '8000-10000'], ['Argentina', '2000', 'male', '75+ years', 'G.I. Generation', 'high_suicides_range', 'medium_population_range', 'high_income_range', '8000-10000'], ['Argentina', '2000', 'male', '55-74 years', 'Silent', 'high_suicides_range', 'high_population_range', 'high_income_range', '8000-10000']]
# chunk = [['Albania', '1987', 'male', '15-24 years', 'Generation X', 'low_suicides_range', 'medium_population_range', 'low_income_range', '0-2000'], ['Albania', '2004', 'female', '75+ years', 'Silent', 'low_suicides_range', 'low_population_range', 'low_income_range', '2000-4000'], ['Albania', '2004', 'female', '25-34 years', 'Generation X', 'low_suicides_range', 'medium_population_range', 'low_income_range', '2000-4000'], ['Argentina', '1990', 'male', '15-24 years', 'Generation X', 'high_suicides_range', 'high_population_range', 'medium_income_range', '4000-6000'], ['Argentina', '1990', 'female', '35-54 years', 'Silent', 'high_suicides_range', 'high_population_range', 'medium_income_range', '4000-6000'], ['Argentina', '1999', 'female', '5-14 years', 'Millenials', 'low_suicides_range', 'high_population_range', 'high_income_range', '8000-10000'], ['Argentina', '2000', 'male', '75+ years', 'G.I. Generation', 'high_suicides_range', 'medium_population_range', 'high_income_range', '8000-10000'], ['Argentina', '2000', 'male', '55-74 years', 'Silent', 'high_suicides_range', 'high_population_range', 'high_income_range', '8000-10000'], ['Argentina', '2007', 'female', '35-54 years', 'Boomers', 'high_suicides_range', 'high_population_range', 'high_income_range', '6000-8000']]
# chunk = [['Albania', '1987', 'male', '15-24 years', 'Generation X', 'low_suicides_range', 'medium_population_range', 'low_income_range', '0-2000'], ['Albania', '2004', 'female', '75+ years', 'Silent', 'low_suicides_range', 'low_population_range', 'low_income_range', '2000-4000'], ['Albania', '2004', 'female', '25-34 years', 'Generation X', 'low_suicides_range', 'medium_population_range', 'low_income_range', '2000-4000'], ['Argentina', '1990', 'male', '15-24 years', 'Generation X', 'high_suicides_range', 'high_population_range', 'medium_income_range', '4000-6000'], ['Argentina', '1990', 'female', '35-54 years', 'Silent', 'high_suicides_range', 'high_population_range', 'medium_income_range', '4000-6000'], ['Argentina', '1999', 'female', '5-14 years', 'Millenials', 'low_suicides_range', 'high_population_range', 'high_income_range', '8000-10000'], ['Argentina', '2000', 'male', '75+ years', 'G.I. Generation', 'high_suicides_range', 'medium_population_range', 'high_income_range', '8000-10000'], ['Argentina', '2000', 'male', '55-74 years', 'Silent', 'high_suicides_range', 'high_population_range', 'high_income_range', '8000-10000'], ['Argentina', '2007', 'female', '35-54 years', 'Boomers', 'high_suicides_range', 'high_population_range', 'high_income_range', '6000-8000'], ['Albania', '2003', 'female', '25-34 years', 'Generation X', 'low_suicides_range', 'medium_population_range', 'low_income_range', '2000-4000']]
# chunk_path = '/tmp/tmpigf5zv2h'
# ############ 2 ############
# chunk = []
# chunk = [['Argentina', '2015', 'female', '55-74 years', 'Boomers', 'medium_suicides_range', 'high_population_range', 'high_income_range', '14000-16000']]
# chunk = [['Argentina', '2015', 'female', '55-74 years', 'Boomers', 'medium_suicides_range', 'high_population_range', 'high_income_range', '14000-16000'], ['Argentina', '2015', 'female', '75+ years', 'Silent', 'medium_suicides_range', 'medium_population_range', 'high_income_range', '14000-16000']]
# chunk = [['Argentina', '2015', 'female', '55-74 years', 'Boomers', 'medium_suicides_range', 'high_population_range', 'high_income_range', '14000-16000'], ['Argentina', '2015', 'female', '75+ years', 'Silent', 'medium_suicides_range', 'medium_population_range', 'high_income_range', '14000-16000'], ['Argentina', '2015', 'male', '5-14 years', 'Generation Z', 'medium_suicides_range', 'high_population_range', 'high_income_range', '14000-16000']]
# chunk = [['Argentina', '2015', 'female', '55-74 years', 'Boomers', 'medium_suicides_range', 'high_population_range', 'high_income_range', '14000-16000'], ['Argentina', '2015', 'female', '75+ years', 'Silent', 'medium_suicides_range', 'medium_population_range', 'high_income_range', '14000-16000'], ['Argentina', '2015', 'male', '5-14 years', 'Generation Z', 'medium_suicides_range', 'high_population_range', 'high_income_range', '14000-16000'], ['Argentina', '2015', 'female', '5-14 years', 'Generation Z', 'low_suicides_range', 'high_population_range', 'high_income_range', '14000-16000']]
# chunk = [['Argentina', '2015', 'female', '55-74 years', 'Boomers', 'medium_suicides_range', 'high_population_range', 'high_income_range', '14000-16000'], ['Argentina', '2015', 'female', '75+ years', 'Silent', 'medium_suicides_range', 'medium_population_range', 'high_income_range', '14000-16000'], ['Argentina', '2015', 'male', '5-14 years', 'Generation Z', 'medium_suicides_range', 'high_population_range', 'high_income_range', '14000-16000'], ['Argentina', '2015', 'female', '5-14 years', 'Generation Z', 'low_suicides_range', 'high_population_range', 'high_income_range', '14000-16000'], ['Armenia', '1990', 'male', '35-54 years', 'Silent', 'low_suicides_range', 'medium_population_range', 'low_income_range', '0-2000']]
# chunk = [['Argentina', '2015', 'female', '55-74 years', 'Boomers', 'medium_suicides_range', 'high_population_range', 'high_income_range', '14000-16000'], ['Argentina', '2015', 'female', '75+ years', 'Silent', 'medium_suicides_range', 'medium_population_range', 'high_income_range', '14000-16000'], ['Argentina', '2015', 'male', '5-14 years', 'Generation Z', 'medium_suicides_range', 'high_population_range', 'high_income_range', '14000-16000'], ['Argentina', '2015', 'female', '5-14 years', 'Generation Z', 'low_suicides_range', 'high_population_range', 'high_income_range', '14000-16000'], ['Armenia', '1990', 'male', '35-54 years', 'Silent', 'low_suicides_range', 'medium_population_range', 'low_income_range', '0-2000'], ['Armenia', '1990', 'male', '75+ years', 'G.I. Generation', 'low_suicides_range', 'low_population_range', 'low_income_range', '0-2000']]
# chunk = [['Argentina', '2015', 'female', '55-74 years', 'Boomers', 'medium_suicides_range', 'high_population_range', 'high_income_range', '14000-16000'], ['Argentina', '2015', 'female', '75+ years', 'Silent', 'medium_suicides_range', 'medium_population_range', 'high_income_range', '14000-16000'], ['Argentina', '2015', 'male', '5-14 years', 'Generation Z', 'medium_suicides_range', 'high_population_range', 'high_income_range', '14000-16000'], ['Argentina', '2015', 'female', '5-14 years', 'Generation Z', 'low_suicides_range', 'high_population_range', 'high_income_range', '14000-16000'], ['Armenia', '1990', 'male', '35-54 years', 'Silent', 'low_suicides_range', 'medium_population_range', 'low_income_range', '0-2000'], ['Armenia', '1990', 'male', '75+ years', 'G.I. Generation', 'low_suicides_range', 'low_population_range', 'low_income_range', '0-2000'], ['Armenia', '1990', 'male', '55-74 years', 'G.I. Generation', 'low_suicides_range', 'medium_population_range', 'low_income_range', '0-2000']]
# chunk = [['Argentina', '2015', 'female', '55-74 years', 'Boomers', 'medium_suicides_range', 'high_population_range', 'high_income_range', '14000-16000'], ['Argentina', '2015', 'female', '75+ years', 'Silent', 'medium_suicides_range', 'medium_population_range', 'high_income_range', '14000-16000'], ['Argentina', '2015', 'male', '5-14 years', 'Generation Z', 'medium_suicides_range', 'high_population_range', 'high_income_range', '14000-16000'], ['Argentina', '2015', 'female', '5-14 years', 'Generation Z', 'low_suicides_range', 'high_population_range', 'high_income_range', '14000-16000'], ['Armenia', '1990', 'male', '35-54 years', 'Silent', 'low_suicides_range', 'medium_population_range', 'low_income_range', '0-2000'], ['Armenia', '1990', 'male', '75+ years', 'G.I. Generation', 'low_suicides_range', 'low_population_range', 'low_income_range', '0-2000'], ['Armenia', '1990', 'male', '55-74 years', 'G.I. Generation', 'low_suicides_range', 'medium_population_range', 'low_income_range', '0-2000'], ['Armenia', '1990', 'male', '5-14 years', 'Generation X', 'low_suicides_range', 'medium_population_range', 'low_income_range', '0-2000']]
# chunk = [['Argentina', '2015', 'female', '55-74 years', 'Boomers', 'medium_suicides_range', 'high_population_range', 'high_income_range', '14000-16000'], ['Argentina', '2015', 'female', '75+ years', 'Silent', 'medium_suicides_range', 'medium_population_range', 'high_income_range', '14000-16000'], ['Argentina', '2015', 'male', '5-14 years', 'Generation Z', 'medium_suicides_range', 'high_population_range', 'high_income_range', '14000-16000'], ['Argentina', '2015', 'female', '5-14 years', 'Generation Z', 'low_suicides_range', 'high_population_range', 'high_income_range', '14000-16000'], ['Armenia', '1990', 'male', '35-54 years', 'Silent', 'low_suicides_range', 'medium_population_range', 'low_income_range', '0-2000'], ['Armenia', '1990', 'male', '75+ years', 'G.I. Generation', 'low_suicides_range', 'low_population_range', 'low_income_range', '0-2000'], ['Armenia', '1990', 'male', '55-74 years', 'G.I. Generation', 'low_suicides_range', 'medium_population_range', 'low_income_range', '0-2000'], ['Armenia', '1990', 'male', '5-14 years', 'Generation X', 'low_suicides_range', 'medium_population_range', 'low_income_range', '0-2000'], ['Armenia', '1991', 'male', '75+ years', 'G.I. Generation', 'low_suicides_range', 'low_population_range', 'low_income_range', '0-2000']]
# chunk_path = '/tmp/tmpqp_aqf_d'
# ############ 2 ############
# chunk = []
# chunk = [['Armenia', '1991', 'male', '25-34 years', 'Boomers', 'low_suicides_range', 'medium_population_range', 'low_income_range', '0-2000']]
# ##########################
